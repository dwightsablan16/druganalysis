# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import compress

import datetime
from dateutil.parser import parse

import math
import os
import copy
import pickle

#import drugLookup

# %%
# Read in data (from pickle file)
file = open('drug_df.dms','rb')
data = pickle.load(file)

# %%
data = data.sort_values(by=['dates'])

# %%
data.iloc[29000:28010,:]
# Out:
#       transaction_id  vendor_id     vendor_name  bitcoin      USD  \
# 59869         '60967       1874         dayglow        0  118.991
# 59888         '60986       1874         dayglow        0  118.991
# 59857         '60955       1874         dayglow        0  118.991
# 59867         '60965       1874         dayglow        0  118.991
# 80814         '81912        123        DDUK-NDD  0.02889    93.39
# 81108         '82206       1629         fun-gee  0.00974    31.48
# 81402         '82500        137  ThePowerCartel   0.1535   496.19
# 81359         '82457        137  ThePowerCartel   0.1535   496.19
# 81439         '82537        592      Mr.Sandman    0.159   513.97
# 60194         '61292       1630   Qualitywhitee        0  57.0837
#
#                                      product_description               dates  \
# 59869                             1 gr Very Good Cocaine 2018-12-16 19:39:31
# 59888                             1 gr Very Good Cocaine 2018-12-16 19:39:31
# 59857                             1 gr Very Good Cocaine 2018-12-16 19:39:31
# 59867                             1 gr Very Good Cocaine 2018-12-16 19:39:31
# 80814              500x TEVA Diazepam Tablets ? FREE NDD 2018-12-16 19:50:39
# 81108  3.5g (1/8oz) Magic Mushrooms P. cubensis amazo... 2018-12-16 19:52:30
# 81402                    28g Ketamine S-Isomer Rock Form 2018-12-16 19:56:28
# 81359                    28g Ketamine S-Isomer Rock Form 2018-12-16 19:56:28
# 81439                                    100 x 110ug LSD 2018-12-16 19:56:40
# 60194                                  2.5 Gram Ketamine 2018-12-16 20:00:48
#
#        drug_prediction
# 59869          cocaine
# 59888          cocaine
# 59857          cocaine
# 59867          cocaine
# 80814  benzodiazepines
# 81108       psilocybin
# 81402         ketamine
# 81359         ketamine
# 81439              lsd
# 60194         ketamine

# %% [markdown]
# ## Split dataset into train/test set

# %%
# Get total number of samples, and number of train/test samples
n_samples = data.shape[0]
n_train = round(n_samples * .75)

# Create training/test set
copied_data = data.copy()

# Convert USD column from objects to integers
# copied_data['USD']= pd.to_numeric
copied_data[["USD"]] = copied_data[["USD"]].apply(pd.to_numeric)


#Create training and testing set
train_set = copied_data.iloc[:n_train,:]
test_set = copied_data.iloc[n_train:,:]

# %%
copied_data.dtypes
# Out:
# transaction_id                 object
# vendor_id                       int64
# vendor_name                    object
# bitcoin                        object
# USD                           float64
# product_description            object
# dates                  datetime64[ns]
# drug_prediction                object
# dtype: object

# %%
#Split testing and training set
p_train = list(train_set['USD'])
v_train = list(train_set['vendor_name'])

p_test = list(test_set['USD'])
v_test = list(test_set['vendor_name'])

# %% [markdown]
# ## Compute P( p | v )

# %% [markdown]
# #### Generate list of bins/categories

# %%
start = 0.00 # first interval price
interval = 20 # length of interval (dollars)

# Create list of price intervals
n_intervals = int(13000/interval) # compute number of intervals
list_of_intervals = [i for i in range(n_intervals)]
slide_amount = interval # amount to slide window (if no overlap desired, set equal to interval)

#Generate the list of bins/intervals
for index in list_of_intervals:
    if list_of_intervals[index] == 0:
        list_of_intervals[index] = 0
    else:
        list_of_intervals[index] = slide_amount
        slide_amount += interval

# print (list_of_intervals)

list_of_intervals= [float(i) for i in list_of_intervals]

print (list_of_intervals)
# Out:
# [0.0, 20.0, 40.0, 60.0, 80.0, 100.0, 120.0, 140.0, 160.0, 180.0, 200.0, 220.0, 240.0, 260.0, 280.0, 300.0, 320.0, 340.0, 360.0, 380.0, 400.0, 420.0, 440.0, 460.0, 480.0, 500.0, 520.0, 540.0, 560.0, 580.0, 600.0, 620.0, 640.0, 660.0, 680.0, 700.0, 720.0, 740.0, 760.0, 780.0, 800.0, 820.0, 840.0, 860.0, 880.0, 900.0, 920.0, 940.0, 960.0, 980.0, 1000.0, 1020.0, 1040.0, 1060.0, 1080.0, 1100.0, 1120.0, 1140.0, 1160.0, 1180.0, 1200.0, 1220.0, 1240.0, 1260.0, 1280.0, 1300.0, 1320.0, 1340.0, 1360.0, 1380.0, 1400.0, 1420.0, 1440.0, 1460.0, 1480.0, 1500.0, 1520.0, 1540.0, 1560.0, 1580.0, 1600.0, 1620.0, 1640.0, 1660.0, 1680.0, 1700.0, 1720.0, 1740.0, 1760.0, 1780.0, 1800.0, 1820.0, 1840.0, 1860.0, 1880.0, 1900.0, 1920.0, 1940.0, 1960.0, 1980.0, 2000.0, 2020.0, 2040.0, 2060.0, 2080.0, 2100.0, 2120.0, 2140.0, 2160.0, 2180.0, 2200.0, 2220.0, 2240.0, 2260.0, 2280.0, 2300.0, 2320.0, 2340.0, 2360.0, 2380.0, 2400.0, 2420.0, 2440.0, 2460.0, 2480.0, 2500.0, 2520.0, 2540.0, 2560.0, 2580.0, 2600.0, 2620.0, 2640.0, 2660.0, 2680.0, 2700.0, 2720.0, 2740.0, 2760.0, 2780.0, 2800.0, 2820.0, 2840.0, 2860.0, 2880.0, 2900.0, 2920.0, 2940.0, 2960.0, 2980.0, 3000.0, 3020.0, 3040.0, 3060.0, 3080.0, 3100.0, 3120.0, 3140.0, 3160.0, 3180.0, 3200.0, 3220.0, 3240.0, 3260.0, 3280.0, 3300.0, 3320.0, 3340.0, 3360.0, 3380.0, 3400.0, 3420.0, 3440.0, 3460.0, 3480.0, 3500.0, 3520.0, 3540.0, 3560.0, 3580.0, 3600.0, 3620.0, 3640.0, 3660.0, 3680.0, 3700.0, 3720.0, 3740.0, 3760.0, 3780.0, 3800.0, 3820.0, 3840.0, 3860.0, 3880.0, 3900.0, 3920.0, 3940.0, 3960.0, 3980.0, 4000.0, 4020.0, 4040.0, 4060.0, 4080.0, 4100.0, 4120.0, 4140.0, 4160.0, 4180.0, 4200.0, 4220.0, 4240.0, 4260.0, 4280.0, 4300.0, 4320.0, 4340.0, 4360.0, 4380.0, 4400.0, 4420.0, 4440.0, 4460.0, 4480.0, 4500.0, 4520.0, 4540.0, 4560.0, 4580.0, 4600.0, 4620.0, 4640.0, 4660.0, 4680.0, 4700.0, 4720.0, 4740.0, 4760.0, 4780.0, 4800.0, 4820.0, 4840.0, 4860.0, 4880.0, 4900.0, 4920.0, 4940.0, 4960.0, 4980.0, 5000.0, 5020.0, 5040.0, 5060.0, 5080.0, 5100.0, 5120.0, 5140.0, 5160.0, 5180.0, 5200.0, 5220.0, 5240.0, 5260.0, 5280.0, 5300.0, 5320.0, 5340.0, 5360.0, 5380.0, 5400.0, 5420.0, 5440.0, 5460.0, 5480.0, 5500.0, 5520.0, 5540.0, 5560.0, 5580.0, 5600.0, 5620.0, 5640.0, 5660.0, 5680.0, 5700.0, 5720.0, 5740.0, 5760.0, 5780.0, 5800.0, 5820.0, 5840.0, 5860.0, 5880.0, 5900.0, 5920.0, 5940.0, 5960.0, 5980.0, 6000.0, 6020.0, 6040.0, 6060.0, 6080.0, 6100.0, 6120.0, 6140.0, 6160.0, 6180.0, 6200.0, 6220.0, 6240.0, 6260.0, 6280.0, 6300.0, 6320.0, 6340.0, 6360.0, 6380.0, 6400.0, 6420.0, 6440.0, 6460.0, 6480.0, 6500.0, 6520.0, 6540.0, 6560.0, 6580.0, 6600.0, 6620.0, 6640.0, 6660.0, 6680.0, 6700.0, 6720.0, 6740.0, 6760.0, 6780.0, 6800.0, 6820.0, 6840.0, 6860.0, 6880.0, 6900.0, 6920.0, 6940.0, 6960.0, 6980.0, 7000.0, 7020.0, 7040.0, 7060.0, 7080.0, 7100.0, 7120.0, 7140.0, 7160.0, 7180.0, 7200.0, 7220.0, 7240.0, 7260.0, 7280.0, 7300.0, 7320.0, 7340.0, 7360.0, 7380.0, 7400.0, 7420.0, 7440.0, 7460.0, 7480.0, 7500.0, 7520.0, 7540.0, 7560.0, 7580.0, 7600.0, 7620.0, 7640.0, 7660.0, 7680.0, 7700.0, 7720.0, 7740.0, 7760.0, 7780.0, 7800.0, 7820.0, 7840.0, 7860.0, 7880.0, 7900.0, 7920.0, 7940.0, 7960.0, 7980.0, 8000.0, 8020.0, 8040.0, 8060.0, 8080.0, 8100.0, 8120.0, 8140.0, 8160.0, 8180.0, 8200.0, 8220.0, 8240.0, 8260.0, 8280.0, 8300.0, 8320.0, 8340.0, 8360.0, 8380.0, 8400.0, 8420.0, 8440.0, 8460.0, 8480.0, 8500.0, 8520.0, 8540.0, 8560.0, 8580.0, 8600.0, 8620.0, 8640.0, 8660.0, 8680.0, 8700.0, 8720.0, 8740.0, 8760.0, 8780.0, 8800.0, 8820.0, 8840.0, 8860.0, 8880.0, 8900.0, 8920.0, 8940.0, 8960.0, 8980.0, 9000.0, 9020.0, 9040.0, 9060.0, 9080.0, 9100.0, 9120.0, 9140.0, 9160.0, 9180.0, 9200.0, 9220.0, 9240.0, 9260.0, 9280.0, 9300.0, 9320.0, 9340.0, 9360.0, 9380.0, 9400.0, 9420.0, 9440.0, 9460.0, 9480.0, 9500.0, 9520.0, 9540.0, 9560.0, 9580.0, 9600.0, 9620.0, 9640.0, 9660.0, 9680.0, 9700.0, 9720.0, 9740.0, 9760.0, 9780.0, 9800.0, 9820.0, 9840.0, 9860.0, 9880.0, 9900.0, 9920.0, 9940.0, 9960.0, 9980.0, 10000.0, 10020.0, 10040.0, 10060.0, 10080.0, 10100.0, 1 ...

# %% [markdown]
# #### Create functions to put price value in categories

# %%
#  Function to check if price is in interval
def priceInInterval(start_price, check_price, length):
    end_price = start_price + length
    cond1 = check_price >= start_price
    cond2 = check_price < end_price
    return(cond1 and cond2)

# Function to classify given price into one of bins
def binPrice(price1, start_prices, length = interval):
    price_bin = [start_price for start_price in start_prices if priceInInterval(start_price, price1,length)]
    if len(price_bin) == 0:
        return(start_prices[-1])
    else:
        return(price_bin[0])

# %% [markdown]
# #### Categorize each price value for each listing

# %%
# train_set.dtypes

# %%
# For given vendor, count the number of transactions in each time_bin
train_set['price_category'] = train_set['USD'].apply(binPrice, start_prices = list_of_intervals)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
train_set.head(6)
# Out:
#       transaction_id  vendor_id     vendor_name bitcoin      USD  \
# 10946         '12044        754     hiddenhands       0   72.532
# 10911         '12009        754     hiddenhands       0   72.532
# 15416         '16514        438  drugpharmacist       0  145.600
# 21600         '22698        962  trotters_stash       0  382.446
# 10955         '12053        754     hiddenhands       0   72.532
# 10947         '12045        754     hiddenhands       0   72.532
#
#                                   product_description               dates  \
# 10946  KETAMINE 3G AAA+++ | OFFER | Next Day Delivery 2018-04-03 19:14:02
# 10911  KETAMINE 3G AAA+++ | OFFER | Next Day Delivery 2018-04-03 19:14:02
# 15416     Bomb Cartel Ice 7g - FREE PRIORITY SHIPPING 2018-04-03 22:19:03
# 21600          7g High Quality Pure #3 Heroin - Uncut 2018-04-04 02:00:13
# 10955  KETAMINE 3G AAA+++ | OFFER | Next Day Delivery 2018-04-04 19:14:02
# 10947  KETAMINE 3G AAA+++ | OFFER | Next Day Delivery 2018-04-04 19:14:02
#
#        drug_prediction  price_category
# 10946         ketamine            60.0
# 10911         ketamine            60.0
# 15416  methamphetamine           140.0
# 21600           heroin           380.0
# 10955         ketamine            60.0
# 10947         ketamine            60.0

# %% [markdown]
# #### Compute probability of vendor given price

# %%
# Get probability for each vendor given a specific time
def getVendorsForPrice(price_bin):
#     Args: Name of a vendor (string)
#     Returns: series, representing proportion of total for each drug
    price_subset = train_set[train_set['price_category'] == price_bin]
    tally = price_subset['vendor_name'].groupby(price_subset['vendor_name']).count()
    return(tally/np.sum(tally))

# %%
# Get list of vendors
_ , vendor_list = pd.factorize(v_train, sort = True)

#Create inverse emission probability dataframe
pvp = pd.DataFrame(columns = vendor_list)
#Insert vendor name column
pvp.insert(0, "price_bin", list_of_intervals)
# Apply function to dataframe
pvp.iloc[:,1:] = pvp['price_bin'].apply(getVendorsForPrice)
# Sort by Vendor name and fill NA values with 0
pvp = pvp.fillna(0)
# Set index to be time
pvp = pvp.set_index('price_bin')

# %% [markdown]
# #### Make Bayes Prediction

# %%
# Get prior probabilities (i.e., probability of each vendor)
vendor_probs = train_set['vendor_name'].value_counts()/np.sum(train_set['vendor_name'].value_counts())
vendor_probs = vendor_probs.sort_index()

# %%
# Create dictionary with best prediction for each drug
pvt_dict = {price_bin : list(pvp.loc[price_bin].sort_values(ascending = False)[:10].index) for price_bin in pvp.index}

# %%
# Function to predict class for each drug in test set
def bayesPredict(obs_seq):
    preds = [pvt_dict[obs] for obs in obs_seq]
    return(preds)

# Get times for testing
test_set['price_category'] = test_set['USD'].apply(binPrice, start_prices = list_of_intervals)
t_test = list(test_set['price_category'])

# Make predictions
test_set['vendor_pred'] = bayesPredict(t_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pvt_dict
# Out:
# {0.0: ['cashcow72',
#   'Gladyman',
#   'gordonflour',
#   'HappyDutch',
#   'fun-gee',
#   'densc0rp',
#   'puremedicinehouse',
#   'PaulReubens',
#   'French_camorra',
#   'deepbay'],
#  20.0: ['mrs.feelgood',
#   'TREES',
#   'MaggieThatcher',
#   'PHARMALABS',
#   'bangalow',
#   'clawedfeats',
#   'einsteingroup',
#   'dankcity',
#   'blueviking',
#   'thatsteroidguy'],
#  40.0: ['mushroomswaterfowl17',
#   'mailordermary2',
#   'NDD-DMT',
#   'JUNY',
#   'ICE-CUBE',
#   'Americansteroids',
#   'muttznutz',
#   'Qualitywhitee',
#   'TheLollipopGuild',
#   'AlanCuring420_UK'],
#  60.0: ['Dr_Seuss_FR',
#   'zouaves',
#   'Grenouillebleu',
#   'StealthPharmacy',
#   'UKXAN',
#   'puremedicinehouse',
#   'ash_williams',
#   'Cash_King',
#   'TheCzechMeth',
#   'hiddenhands'],
#  80.0: ['BudWorld',
#   'JerryGarcia',
#   'Migosicegang',
#   'green.goddess',
#   'DOPE_CHEF',
#   'aussieroidmuncherr',
#   'frosties2014',
#   'StealthPharmacy',
#   'ScarlettsK',
#   'MoonBanana'],
#  100.0: ['blueviking',
#   'StealthPharmacy',
#   'CaliDrugCo',
#   'drugpharmacist',
#   'zouaves',
#   'HerbinLegend',
#   'PackzRus',
#   'Smokey1884',
#   'LightBroker',
#   'rickandmortyshop'],
#  120.0: ['DrRubiks',
#   'pastrydam',
#   'Theshaman',
#   'PackzRus',
#   'tinyrock',
#   'Boliko',
#   'Manny101_DM',
#   'pabst_paul',
#   'MrBlow',
#   'CryptoICE'],
#  140.0: ['drugpharmacist',
#   'hiddenshadows',
#   'rickandmortyshop',
#   'PopeyeUK',
#   'drugkingz',
#   'MrBlow',
#   'BuddyBLAZE',
#   'Hyperamigo',
#   '420HighStreet',
#   'puremedicinehouse'],
#  160.0: ['originaldragoncove',
#   'CalSource',
#   'Discover',
#   'avalanche',
#   '24-7SmokeShop',
#   'PackzRus',
#   'pastrydam',
#   '9incecloud',
#   'Manny101_DM',
#   'DispensaryDash'],
#  180.0: ['DrOxy',
#   'MoonBanana',
#   'undergroundcoco',
#   'largomonkey',
#   'PILLSandWHITE',
#   'BlackSheepSquadron',
#   'DDUK-NDD',
#   'CaliCartel',
#   'UKXAN',
#   'highrollers'],
#  200.0: ['green.goddess',
#   'Aphelion',
#   'UKXAN',
#   'tinyrock',
#   'MercenaryGB',
#   'BlackSheepSquadron',
#   'einsteingroup',
#   'AlanCuring420_UK',
#   'sunshining',
#   'MeltDown'],
#  220.0: ['ChillChem',
#   'tonystarkweed',
#   'Aphelion',
#   'amsterdamflex',
#   'MeltDown',
#   'DMT-lovestore',
#   'DRUGPOOL',
#   'Mr.Sandman',
#   'MercenaryGB',
#   'sunshining'],
#  240.0: ['pastrydam',
#   'Super_Shards',
#   'NHS_UK',
#   'highrollers',
#   'Mr.Sandman',
#   'sunshining',
#   'tonystarkweed',
#   'DRUGPOOL',
#   'projeccao',
#   'MrBlow'],
#  260.0: ['fantasy44',
#   'TheLollipopGuild',
#   'largomonkey',
#   'pastrydam',
#   'incorporatedv2',
#   'WhiteCastle',
#   'pabst_paul',
#   'rickandmortyshop',
#   'MrBlow',
#   'blueviking'],
#  280.0: ['onechance',
#   'hiddenshadows',
#   'premiumcoke',
#   'MrMaserati',
#   'incorporatedv2',
#   'pastrydam',
#   'sunshining',
#   'value.lucid',
#   'superdrug',
#   'pabst_paul'],
#  300.0: ['incorporatedv2',
#   'pastrydam',
#   'czechairlines',
#   'pabst_paul',
#   'Theshaman',
#   'value.lucid',
#   'MrBlow',
#   'superdrug',
#   'Manny101_DM',
#   'UKXAN'],
#  320.0: ['mailman-xans',
#   'incorporatedv2',
#   'sakari',
#   'Theshaman',
#   'MrMaserati',
#   'sunshining',
#   'ukbk',
#   'pastrydam',
#   'pabst_paul',
#   'value.lucid'],
#  340.0: ['Subs_Unlimited',
#   'therealLBZ',
#   'CaliCartel',
#   'A1CRACK',
#   'TheLollipopGuild',
#   'sakari',
#   'Theshaman',
#   'incorporatedv2',
#   'Manny101_DM',
#   'pabst_paul'],
#  360.0: ['weedjs',
#   'karmaking',
#   'OneStop',
#   'BudWorld',
#   'aussiebud',
#   'czechairlines',
#   'Theshaman',
#   'incorporatedv2',
#   'projeccao',
#   'GRUENEWALDSCAVE'],
#  380.0: ['trotters_stash',
#   'aussiebud',
#   'OneStop',
#   'incorporatedv2',
#   'sakari',
#   'GRUENEWALDSCAVE',
#   'Theshaman',
#   'ChillChem',
#   'th3professionals',
#   'pabst_paul'],
#  400.0: ['Kman3000',
#   'superdrug',
#   'HerbinLegend',
#   'incorporatedv2',
#   'MrMaserati',
#   'Theshaman',
#   'OneStop',
#   'Manny101_DM',
#   'ChillChem',
#   'drugkingz'],
#  420.0: ['superdrug',
#   'OneStop',
#   'incorporatedv2',
#   'SigmaOmicron',
#   'MrMaserati',
#   'value.lucid',
#   'ChillChem',
#   'projeccao',
#   'NordicBars',
#   'sakari'],
#  440.0: ['drugkingz',
#   'th3professionals',
#   'GRUENEWALDSCAVE',
#   'Duckthugg',
#   'incorporatedv2',
#   'Manny101_DM',
#   'tinyrock',
#   'Theshaman',
#   'DrOxy',
#   'MrMaserati'],
#  460.0: ['CryptoICE',
#   'th3professionals',
#   'originaldragoncove',
#   'GRUENEWALDSCAVE',
#   'incorporatedv2',
#   'TheWisdomGoddess',
#   'OneStop',
#   'drugkingz',
#   'Theshaman',
#   'DoktorGreen'],
#  480.0: ['CaliDrugCo',
#   'DrOxy',
#   'superdrug',
#   'GRUENEWALDSCAVE',
#   'hiddenhands',
#   'incorporatedv2',
#   'Theshaman',
#   'th3professionals',
#   'sakari',
#   'Cocaineandbrandy'],
#  500.0: ['SNIFFKING',
#   'DrOxy',
#   'sthompson',
#   'TheLollipopGuild',
#   'DoktorGreen',
#   'HQoz',
#   'Manny101_DM',
#   'th3professionals',
#   'Dr_Seuss_FR',
#   'sakari'],
#  520.0: ['420HighStreet',
#   'sthompson',
#   'DrOxy',
#   'drugkingz',
#   'NHS_UK',
#   'superdrug',
#   'th3professionals',
#   'JerryGarcia',
#   'HQoz',
#   'zouaves'],
#  540.0: ['GRUENEWALDSCAVE',
#   'sthompson',
#   'th3professionals',
#   'zouaves',
#   'PopeyeUK',
#   'radarbreeder',
#   'DoktorGreen',
#   'SigmaOmicron',
#   'Migosicegang',
#   'MercenaryGB'],
#  560.0: ['Mastery',
#   'th3professionals',
#   'CalSource',
#   'zouaves',
#   'Recettear',
#   'drugkingz',
#   'sthompson',
#   'NHS_UK',
#   'ChillChem',
#   'GRUENEWALDSCAVE'],
#  580.0: ['originaldragoncove',
#   'th3professionals',
#   'zouaves',
#   'DoktorGreen',
#   'Grenouillebleu',
#   'HQoz',
#   'Cocaineandbrandy',
#   'ThePowerCartel',
#   'sthompson',
#   'GRUENEWALDSCAVE'],
#  600.0: ['largomonkey',
#   'zouaves',
#   'SigmaOmicron',
#   'th3professionals',
#   'sthompson',
#   'ThePowerCartel',
#   'hiddenhands',
#   'radarbreeder',
#   'HappyDutch',
#   'LiLXanax'],
#  620.0: ['SigmaOmicron',
#   'th3professionals',
#   'ChillChem',
#   'zouaves',
#   'Cocaineandbrandy',
#   'GRUENEWALDSCAVE',
#   'value.lucid',
#   'DoktorGreen',
#   'sthompson',
#   'MercenaryGB'],
#  640.0: ['SigmaOmicron',
#   'ChillChem',
#   'GRUENEWALDSCAVE',
#   'radarbreeder',
#   'ThePowerCartel',
#   'Grenouillebleu',
#   'HQoz',
#   'hiddenhands',
#   'drugkingz',
#   'DoktorGreen'],
#  660.0: ['weedjs',
#   'ChillChem',
#   'SigmaOmicron',
#   'zouaves',
#   'GRUENEWALDSCAVE',
#   'th3professionals',
#   'ThePowerCartel',
#   'hiddenhands',
#   'MoonBanana',
#   'Migosicegang'],
#  680.0: ['zouaves',
#   'ChillChem',
#   'GRUENEWALDSCAVE',
#   'SigmaOmicron',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  700.0: ['ChillChem',
#   'zouaves',
#   'Multi',
#   'Boliko',
#   'DoktorGreen',
#   'GRUENEWALDSCAVE',
#   'ThePowerCartel',
#   'RealPharmaceuticals',
#   'LySanDerspooner',
#   'MoonBanana'],
#  720.0: ['xangod',
#   'Boliko',
#   'value.lucid',
#   'SigmaOmicron',
#   'Multi',
#   'DoktorGreen',
#   'Cocaineandbrandy',
#   'ThePowerCartel',
#   'sthompson',
#   'amsterdamflex'],
#  740.0: ['zouaves',
#   'ChillChem',
#   'Boliko',
#   'HQoz',
#   'aussieroidmuncherr',
#   'sthompson',
#   'SigmaOmicron',
#   'DoktorGreen',
#   'MaggieThatcher',
#   'MoonBanana'],
#  760.0: ['zouaves',
#   'Boliko',
#   'HQoz',
#   'SigmaOmicron',
#   'NHS_UK',
#   'PopeyeUK',
#   'Cocaineandbrandy',
#   '9incecloud',
#   'MaggieThatcher',
#   'Mr.Postman'],
#  780.0: ['420HighStreet',
#   'Cocaineandbrandy',
#   'PopeyeUK',
#   'zouaves',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  800.0: ['PopeyeUK',
#   'Cocaineandbrandy',
#   'superdrug',
#   'zouaves',
#   'Hyperamigo',
#   'amsterdamflex',
#   'Port-Royal',
#   'LiLXanax',
#   'Migosicegang',
#   'MercenaryGB'],
#  820.0: ['LiLXanax',
#   'Cocaineandbrandy',
#   'PopeyeUK',
#   'ICE-CUBE',
#   'zouaves',
#   'NHS_UK',
#   'superdrug',
#   'Boliko',
#   'HQoz',
#   'PleasureIsland'],
#  840.0: ['Subs_Unlimited',
#   'Cocaineandbrandy',
#   'HQoz',
#   'NHS_UK',
#   'PopeyeUK',
#   'ThePowerCartel',
#   'zouaves',
#   'superdrug',
#   'Boliko',
#   'amsterdamflex'],
#  860.0: ['Cocaineandbrandy',
#   'HQoz',
#   'NHS_UK',
#   'ThePowerCartel',
#   'PopeyeUK',
#   'ICE-CUBE',
#   'Manny101_DM',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang'],
#  880.0: ['HQoz',
#   'PopeyeUK',
#   'zouaves',
#   'HonestTrader',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  900.0: ['MrMaserati',
#   'HQoz',
#   'aussieroidmuncherr',
#   'Cocaineandbrandy',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  920.0: ['Migosicegang',
#   'SNIFFKING',
#   'premiumcoke',
#   'HQoz',
#   'RealPharmaceuticals',
#   'LightBroker',
#   'MoonBanana',
#   'Recettear',
#   'MercenaryGB',
#   'MeltDown'],
#  940.0: ['Cocaineandbrandy',
#   'ThePowerCartel',
#   'value.lucid',
#   'PopeyeUK',
#   'Boliko',
#   'zouaves',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB'],
#  960.0: ['ThePowerCartel',
#   'PopeyeUK',
#   'amsterdamflex',
#   'Cocaineandbrandy',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  980.0: ['ThePowerCartel',
#   'Cocaineandbrandy',
#   'DDUK-NDD',
#   'HQoz',
#   'Mr.Sandman',
#   'ICE-CUBE',
#   'JUNY',
#   'HonestTrader',
#   'Mr.Postman',
#   'MoonBanana'],
#  1000.0: ['ThePowerCartel',
#   'Cocaineandbrandy',
#   'Mr.Sandman',
#   'zouaves',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1020.0: ['Mr.Sandman',
#   'HQoz',
#   'Cocaineandbrandy',
#   'RoyalMail',
#   'ThePowerCartel',
#   'PopeyeUK',
#   'RayfulWhyte',
#   'LiLXanax',
#   'Migosicegang',
#   'MercenaryGB'],
#  1040.0: ['Mastery',
#   'HerbinLegend',
#   'Mr.Sandman',
#   'PopeyeUK',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  1060.0: ['Cocaineandbrandy',
#   'ThePowerCartel',
#   'zouaves',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1080.0: ['avalanche',
#   'PopeyeUK',
#   'zouaves',
#   'LightBroker',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1100.0: ['ThePowerCartel',
#   'PopeyeUK',
#   'zouaves',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1120.0: ['HQoz',
#   'ThePowerCartel',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1140.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1160.0: ['PopeyeUK',
#   'HQoz',
#   'ThePowerCartel',
#   'Boliko',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1180.0: ['Boliko',
#   'BudWorld',
#   'zouaves',
#   'LySanDerspooner',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  1200.0: ['Boliko',
#   'Hyperamigo',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1220.0: ['PopeyeUK',
#   'HQoz',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1240.0: ['Boliko',
#   'BudWorld',
#   'zouaves',
#   'LySanDerspooner',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  1260.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1300.0: ['blueviking',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1320.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1340.0: ['largomonkey',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1360.0: ['Hyperamigo',
#   'Boliko',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1380.0: ['therealLBZ',
#   'Boliko',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1400.0: ['th3professionals',
#   'aussieroidmuncherr',
#   'Hyperamigo',
#   'zouaves',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1420.0: ['th3professionals',
#   'zouaves',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1440.0: ['th3professionals',
#   'zouaves',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1460.0: ['aussieroidmuncherr',
#   'th3professionals',
#   'zouaves',
#   'Mr.Sandman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1480.0: ['th3professionals',
#   'aussieroidmuncherr',
#   'Qualitywhitee',
#   'zouaves',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1500.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1520.0: ['aussieroidmuncherr',
#   'th3professionals',
#   'zouaves',
#   'Mr.Sandman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1540.0: ['aussieroidmuncherr',
#   'ukbk',
#   'zouaves',
#   'LightBroker',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1560.0: ['DDUK-NDD',
#   'th3professionals',
#   'aussieroidmuncherr',
#   'Boliko',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1580.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1600.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1620.0: ['LiLXanax',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1640.0: ['CryptoICE',
#   'aussieroidmuncherr',
#   'zouaves',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1660.0: ['PopeyeUK',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1680.0: ['MrBlow',
#   'PopeyeUK',
#   'th3professionals',
#   'PackzRus',
#   'aussieroidmuncherr',
#   'LightBroker',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown'],
#  1700.0: ['PopeyeUK',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1720.0: ['g00d00',
#   'PopeyeUK',
#   'zouaves',
#   'LiLXanax',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1740.0: ['PopeyeUK',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1760.0: ['SNIFFKING',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1780.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1800.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1820.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1840.0: ['g00d00',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1860.0: ['th3professionals',
#   'PopeyeUK',
#   'zouaves',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1880.0: ['GRUENEWALDSCAVE',
#   'PopeyeUK',
#   'zouaves',
#   'LiLXanax',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  1900.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1920.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  1940.0: ['aussieroidmuncherr',
#   'GRUENEWALDSCAVE',
#   'zouaves',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1960.0: ['avalanche',
#   'GRUENEWALDSCAVE',
#   'zouaves',
#   'LySanDerspooner',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  1980.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2000.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2020.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2040.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2060.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2080.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2100.0: ['originaldragoncove',
#   'zouaves',
#   'HQoz',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2120.0: ['g00d00',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2140.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2160.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2180.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2200.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2220.0: ['DoktorGreen',
#   'zouaves',
#   'HQoz',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2240.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2260.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2300.0: ['aussieroidmuncherr',
#   'zouaves',
#   'RoyalMail',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2320.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2340.0: ['LiLXanax',
#   'DDUK-NDD',
#   'PopeyeUK',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  2360.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2380.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2400.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2420.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2440.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2460.0: ['MrBlow',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2480.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2500.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2520.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2540.0: ['DDUK-NDD',
#   'ukbk',
#   'LightBroker',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  2560.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2580.0: ['DDUK-NDD',
#   'ukbk',
#   'LightBroker',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery'],
#  2600.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2620.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2640.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2660.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2680.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2700.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2720.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2740.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2760.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2780.0: ['ukbk',
#   'incorporatedv2',
#   'zouaves',
#   'LiLXanax',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2800.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2820.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2840.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2860.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2880.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2900.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  2920.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2940.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2960.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  2980.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3000.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3020.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3040.0: ['MeltDown',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3060.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3080.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3100.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3120.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3140.0: ['incorporatedv2',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3160.0: ['th3professionals',
#   'zouaves',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3180.0: ['MrBlow',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3200.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3220.0: ['Migosicegang',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3240.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3260.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3300.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3320.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3340.0: ['th3professionals',
#   'zouaves',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3360.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3380.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3400.0: ['DDUK-NDD',
#   'MrBlow',
#   'Mr.Sandman',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3420.0: ['ukbk',
#   'incorporatedv2',
#   'zouaves',
#   'LiLXanax',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3440.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3460.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3480.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3500.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3520.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3540.0: ['th3professionals',
#   'incorporatedv2',
#   'zouaves',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3560.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3580.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3600.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3620.0: ['incorporatedv2',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3640.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3660.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3680.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3700.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3720.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3740.0: ['LiLXanax',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3760.0: ['SigmaOmicron',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3780.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3800.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3820.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3840.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3860.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3880.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3900.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3920.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3940.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  3960.0: ['UKgradeAproducts',
#   'zouaves',
#   'MrBlow',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  3980.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4000.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4020.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4040.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4060.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4080.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4100.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4120.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  4140.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4160.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4180.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4200.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4220.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4240.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4260.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4300.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4320.0: ['SigmaOmicron',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  4340.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4360.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4380.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4400.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4420.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4440.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4460.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4480.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4500.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4520.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4540.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4560.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4580.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4600.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4620.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4640.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4660.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4680.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4700.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4720.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4740.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4760.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  4780.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4800.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4820.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4840.0: ['MeltDown',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4860.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4880.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4900.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4920.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4940.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4960.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  4980.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5000.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5020.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5040.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5060.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5080.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5100.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5120.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5140.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5160.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5180.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5200.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5220.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5240.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5260.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5300.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  5320.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  5340.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  5360.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5380.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5400.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5420.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  5440.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5460.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5480.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5500.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5520.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5540.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5560.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  5580.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  5600.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5620.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5640.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  5660.0: ['ukbk',
#   'zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
# ...
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11140.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11160.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11180.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11200.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11220.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11240.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11260.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11300.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11320.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11340.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11360.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11380.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11400.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11420.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11440.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11460.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11480.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11500.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11520.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11540.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11560.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11580.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11600.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11620.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11640.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11660.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11680.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11700.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11720.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11740.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11760.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11780.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11800.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11820.0: ['Dame2Pique',
#   'zouaves',
#   'HQoz',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM'],
#  11840.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11860.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11880.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11900.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11920.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11940.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11960.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  11980.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12000.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12020.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12040.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12060.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12080.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12100.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12120.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12140.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12160.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12180.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12200.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12220.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12240.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12260.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12280.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12300.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12320.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12340.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12360.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12380.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12400.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12420.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12440.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12460.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12480.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12500.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12520.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12540.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12560.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12580.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12600.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12620.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12640.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12660.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12680.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12700.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12720.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12740.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12760.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12780.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12800.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12820.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12840.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12860.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12880.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12900.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12920.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12940.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12960.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher'],
#  12980.0: ['zouaves',
#   'LightBroker',
#   'Mr.Postman',
#   'MoonBanana',
#   'Migosicegang',
#   'MercenaryGB',
#   'MeltDown',
#   'Mastery',
#   'Manny101_DM',
#   'MaggieThatcher']}

# %%
# Compute 'top n' accuracy
def get_top_n(df, n):
    q = zip(df['vendor_name'], df['vendor_pred'])
    if n == 1:
        ar = [samp[0] == samp[1][0] for samp in q]
    else:
        ar = [samp[0] in samp[1][:n] for samp in q]
    acc = np.sum(ar)/len(ar)
    return(round(acc,4))

# %%
print('Time interval for bin:',interval, 'dollar.')
print('Top 1 accuracy :',get_top_n(test_set, 1))
print('Top 2 accuracy :',get_top_n(test_set, 2))
print('Top 3 accuracy :',get_top_n(test_set, 3))
print('Top 5 accuracy :',get_top_n(test_set, 5))
print('Top 10 accuracy:',get_top_n(test_set, 10))
# Out:
# Time interval for bin: 20 dollar.
# Top 1 accuracy : 0.0723
# Top 2 accuracy : 0.1083
# Top 3 accuracy : 0.1495
# Top 5 accuracy : 0.1923
# Top 10 accuracy: 0.2843

# %% [markdown]
# #### Export data to pickle file

# %%
#concatenate training and testing set
drug_and_price = pd.concat([train_set, test_set],sort = False)

# %%
# Export to file
import pickle
file = open('drug_and_price.pkl','wb')
pickle.dump(drug_and_price, file)
file.close()

file = open('drug_and_price_train.pkl','wb')
pickle.dump(train_set, file)
file.close()

file = open('drug_and_price_test.pkl','wb')
pickle.dump(test_set, file)
file.close()

# %% [markdown]
# #### Price plots

# %%
# Price plots
plot_price = data[['vendor_name', 'USD']].copy()

vendor_names = data['vendor_name'].tolist()

USD = data['USD'].tolist()

# price_graphs = pd.DataFrame({'vendor_name': vendor_names, 'USD': USD})

# price_graphs.groupby('vendor_name').hist()
# print (data['USD'].hist(by=data['vendor_name']))
